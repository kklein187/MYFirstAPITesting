# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# REST-API
# Representational State Transfer - Application Programming Interface
# Dr.Roy Fielding

# %% [markdown]
# # Abgabe:
# 1. Lege eine Person (z.B. deinen Sitznachbarn) als Testperson im API auf https://datahouse.pythonanywhere.com/api/Testperson/ mit dem Web- Formular an
# 2. Frage diese Person im Ipython Notebook aus dem REST - API mittels GET - REQUEST ab und gib sie mit einem print - Befehl aus
# 3. Analysiere die JSON - Darstellung des API und gib an, a) um welche JSON - Datenstruktur es sich laut https://json.org bei dieser Webseite handelt:
#  ![image.png](attachment:image.png)
#
#     b) Ergänze einen Screenshot der passenden Datenstrukturen ![image.png](attachment:image-2.png)
#
#     ... und c) begründe (ACHTUNG: es kann sich um eine Kombination mehrerer JSON - Datenstrukturen handeln.)
#
# 4. Lege eine weitere Person mittels post request an und gib die "response" mittels print - Befehl aus
# 5. Führe abschließend einen get - request auf das REST - API aus, erzeuge einen DataFrame aus der zurückgegebenen Liste und gib die ersten 25 Zeilen
# des DataFrame aus. Ergänze dazu als Markdown oder als Kommentar den zutreffenden "Timestamp"
#
# #### Hinweis: Die Teilaufgaben 1 - 5 sollten im Notebook dokumentiert werden. Das Notebook enthält bereits einzelne Code - Bestandteile, die als Hilfestellung verwendet werden können, achte jedoch auf eine nachvollziehbare Struktur!

# %% [markdown]
# Die json Datenstruktur handelt sich es um eine Kobination aus Arrays und Objects
# ![image.png](attachment:image.png)

# %%
#%pip install requests
#%pip install pandas
import requests
import json 
import pandas as pd
url = 'https://datahouse.pythonanywhere.com/api/Testperson/'

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
response = requests.get(url)
#print(response)
testdata=response.json()
#print(testdata)
#print(response.raw)
#print(response.text)
print(type(testdata))
#print(testdata[0]["id"])
# for i in range(len(testdata)):
#     if testdata[i]["name"] == "Philip Feitsch":
#         print(testdata[i])
#     else:pass
response1 = requests.get(url,params={
    "name": "Philip Feitsch","alias" : "PF"
})
print(response1.text)
# Out:
# <class 'list'>
# {'id': 76, 'name': 'Philip Feitsch', 'alias': 'PF', 'rec_time': '2023-04-14T06:33:18.683726Z', 'pers_uuid': '67509b44-ccaf-4127-990d-4b1fa1b62fc0'}
# [{"id":76,"name":"Philip Feitsch","alias":"PF","rec_time":"2023-04-14T06:33:18.683726Z","pers_uuid":"67509b44-ccaf-4127-990d-4b1fa1b62fc0"}]

# %%
type(testdata)
df=pd.DataFrame(testdata)
print(df)
# Out:
#      id             name                         alias  \
# 0   107          Kajetan                         Daddy
# 1   106     Apollo Creed                          king
# 2   105           chemie                        scheiß
# 3   104             Luis                         Luigi
# 4   103              SAP  Systeme Anwendungen Produkte
# 5   102              SAP                          King
# 6   101              SAP                          King
# 7   100            Kerem                         Karim
# 8    99              SAP                          King
# 18  2023-04-14T07:13:34.909261Z  bd9a25d7-7dc8-4c70-9152-288de118493c
# 19  2023-04-14T07:12:46.025449Z  9eea8ff6-6c0f-4422-a8dd-5eab48771ca0
# 20  2023-04-14T07:06:24.947806Z  46b5029d-3ac8-4834-9e95-9d028d40fe71
# 21  2023-04-14T07:05:21.571165Z  c8efb12f-3028-4529-bd83-5184297bb5c8
# 22  2023-04-14T07:04:38.188431Z  2613895d-4b25-410d-9953-4d2cc3c0c8fe
# 23  2023-04-14T07:04:24.526009Z  e6003fcf-b1c1-4ca8-8c23-52a42b7181ed
# 24  2023-04-14T07:04:12.930922Z  627fc000-e29d-4b09-af1b-881e12cb6979
# 25  2023-04-14T07:02:50.348853Z  1f2bb25e-a45d-45be-a29d-59e20ce42d64
# 26  2023-04-14T06:39:55.516451Z  9f8e48fb-9f7e-4c04-8aec-9ed1cdbe0415
# 27  2023-04-14T06:38:44.827455Z  daa066fc-30d5-4e4a-9d0f-c5ec66993540
# 28  2023-04-14T06:37:51.731909Z  be9b9ab7-6370-453a-b4ae-0a229cbbd7c5
# 29  2023-04-14T06:37:36.580772Z  d88cb5c2-ff4a-4c5a-841d-1912059a0bcd
# 30  2023-04-14T06:36:02.394373Z  71eca451-b561-4381-a53d-ca04b5ee102b
# 31  2023-04-14T06:33:18.683726Z  67509b44-ccaf-4127-990d-4b1fa1b62fc0
# 32  2023-03-31T19:43:36.389304Z  6741bbc9-181e-484f-b1de-5d3a964aefbc

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# post request trial 
response1 = requests.post(url,json={
    "name": "Kerem","alias" : "Karim"
    # ???? another columd is an additional key- value pair
})
print(response1.text)
# Out:
# {"id":100,"name":"Kerem","alias":"Karim","rec_time":"2023-04-14T07:26:20.684228Z","pers_uuid":"7c8c3052-346f-4198-999e-3f01062ad0aa"}

# %%
df=pd.DataFrame(testdata)
print(df[:26])
# Out:
#      id             name                         alias  \
# 0   107          Kajetan                         Daddy
# 1   106     Apollo Creed                          king
# 2   105           chemie                        scheiß
# 3   104             Luis                         Luigi
# 4   103              SAP  Systeme Anwendungen Produkte
# 5   102              SAP                          King
# 6   101              SAP                          King
# 7   100            Kerem                         Karim
# 8    99              SAP                          King
# 9    98              SAP                          King
# 10   97              SAP                          King
# 11   96           Fabian                            DF
# 12   95          Kajetan                         Daddy
# 13   94            Rocky                             R
# 14   93      Noah Bodner                            NB
# 15   92  Przemyslaw Czak                            PC
# 16   91  Przemyslaw Czak                            PC
# 17   90      Endlich Pia                            EP
# 18   89           Amogus                           sus
# 19   88          Kajetan                         Daddy
# 20   87          Kajetan                         Daddy
# 21   86         Dj Prolo                    prolomusic
# 22   85          Kajetan                         Daddy
# 23   84          Kajetan                         Daddy
